# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torch.utils.tensorboard import SummaryWriter  # to print to tensorboard

import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from sdmetrics.reports.utils import get_column_plot, get_column_pair_plot
from sdmetrics.reports.single_table import QualityReport
from sdv import Metadata
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data pre-process

# %% [markdown]
# ## Read cleaned data

# %%
# df = pd.read_csv('../OlympicHistory/CleanedData.csv')
df = pd.read_csv('../OlympicHistory/CleanedData.csv').iloc[0:10000, :]

# %%
df
# Out:
#         ID                              Name Sex   Age  Height  Weight  \
# 0        1                         A Dijiang   M  24.0   180.0    80.0
# 1        2                          A Lamusi   M  23.0   170.0    60.0
# 2        3               Gunnar Nielsen Aaby   M  24.0   175.0    71.0
# 3        4              Edgar Lindenau Aabye   M  34.0   182.0    95.0
# 4        5          Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...    ...                               ...  ..   ...     ...     ...
# 9995  7390         Serhiy Pavlovych Baltacha   M  22.0   181.0    75.0
# 9996  7391                    Eduardo Baltar   M  19.0   160.0    48.0
# 9997  7392                  Dimitrios Baltas   M  34.0   175.0    70.0
# 9998  7393  Nikolaos Baltatzis-Mavrokordatos   M  25.0   185.0    84.0
# 9999  7393  Nikolaos Baltatzis-Mavrokordatos   M  25.0   185.0    84.0
#
#                 Team  NOC  Year  Season       City          Sport  \
# 0              China  CHN  1992  Summer  Barcelona     Basketball
# 1              China  CHN  2012  Summer     London           Judo
# 2            Denmark  DEN  1920  Summer  Antwerpen       Football
# 3     Denmark/Sweden  DEN  1900  Summer      Paris     Tug-Of-War
# 4        Netherlands  NED  1988  Winter    Calgary  Speed Skating
# ...              ...  ...   ...     ...        ...            ...
# 9995    Soviet Union  URS  1980  Summer     Moskva       Football
# 9996     Philippines  PHI  1976  Summer   Montreal         Boxing
# 9997          Greece  GRE  1992  Summer  Barcelona       Shooting
# 9998          Greece  GRE  1920  Summer  Antwerpen     Water Polo
# 9999          Greece  GRE  1924  Summer      Paris     Water Polo
#
#                                      Event   Medal  AOS  AOE   YOB
# 0              Basketball Men's Basketball  Thanks    1    1  1968
# 1             Judo Men's Extra-Lightweight  Thanks    1    1  1989
# 2                  Football Men's Football  Thanks    1    1  1896
# 3              Tug-Of-War Men's Tug-Of-War    Gold    1    1  1866
# 4         Speed Skating Women's 500 metres  Thanks    1    2  1967
# ...                                    ...     ...  ...  ...   ...
# 9995               Football Men's Football  Bronze    1    1  1958
# 9996          Boxing Men's Light-Flyweight  Thanks    1    1  1957
# 9997  Shooting Men's Air Pistol, 10 metres  Thanks    1    3  1958
# 9998           Water Polo Men's Water Polo  Thanks    1    1  1895
# 9999           Water Polo Men's Water Polo  Thanks    1    1  1899
#
# [10000 rows x 17 columns]

# %% [markdown]
# ## Find continuous data

# %%
df_conti = df[['Age','Height', 'Weight']]
df_conti
# Out:
#        Age  Height  Weight
# 0     24.0   180.0    80.0
# 1     23.0   170.0    60.0
# 2     24.0   175.0    71.0
# 3     34.0   182.0    95.0
# 4     21.0   185.0    82.0
# ...    ...     ...     ...
# 9995  22.0   181.0    75.0
# 9996  19.0   160.0    48.0
# 9997  34.0   175.0    70.0
# 9998  25.0   185.0    84.0
# 9999  25.0   185.0    84.0
#
# [10000 rows x 3 columns]

# %% [markdown]
# ## Normalization

# %%
def max_abs_norm(data: pd.DataFrame, column: str):
    max_val = data[column].abs().max()
    data[column] = data[column] / max_val
    return data, max_val


def min_max_norm(data: pd.DataFrame, column: str):
    min_val = data[column].min()
    max_val = data[column].max()
    data[column] = (data[column] - min_val) / (max_val - min_val)
    return data, min_val, max_val


def standardization(data: pd.DataFrame, column: str):
    mean_val = data[column].mean()
    std_val = data[column].std()
    data[column] = (data[column] - mean_val) / std_val
    return data, mean_val, std_val


def max_abs_denorm(data: pd.DataFrame, column: str, norm_dict: dict):
    max_val = norm_dict[column]
    data[column] = data[column] * max_val
    return data


def min_max_denorm(data: pd.DataFrame, column: str, norm_dict: dict):
    min_val = norm_dict[column][0]
    max_val = norm_dict[column][1]
    data[column] = data[column] * (max_val - min_val) + min_val
    return data


def destandardization(data: pd.DataFrame, column: str, norm_dict: dict):
    mean_val = norm_dict[column][0]
    std_val = norm_dict[column][1]
    data[column] = data[column] * std_val + mean_val
    return data

# %%
def norm(data: pd.DataFrame, columns: [], norm_types: []):
    norm_dict = {}
    for i in range(len(columns)):
        if norm_types[i] == 'max_abs':
            data, max_val = max_abs_norm(data, columns[i])
            norm_dict.update({columns[i]: max_val})
        
        if norm_types[i] == 'min_max':
            data, min_val, max_val = min_max_norm(data, columns[i])
            norm_dict.update({columns[i]: [min_val, max_val]})
            
        if norm_types[i] == 'standard':
            data, mean_val, std_val = standardization(data, columns[i])
            norm_dict.update({columns[i]: [mean_val, std_val]})

    return data, norm_dict

def denorm(data: pd.DataFrame, columns: [], norm_types: [], norm_dict: dict):
    for i in range(len(columns)):
        if norm_types[i] == 'max_abs':
            data = max_abs_denorm(data, columns[i], norm_dict)
        
        if norm_types[i] == 'min_max':
            data = min_max_denorm(data, columns[i], norm_dict)
        
        if norm_types[i] == 'standard':
            data = destandardization(data, columns[i], norm_dict)
    
    return data

# %%
norm_list = ['Age', 'Height', 'Weight']
norm_types = ['standard', 'standard', 'standard']
df_conti_norm, dict_conti = norm(df_conti, norm_list, norm_types)
df_conti_norm
# Out:
#            Age    Height    Weight
# 0    -0.268326  0.425031  0.591794
# 1    -0.438175 -0.635134 -0.889469
# 2    -0.268326 -0.105052 -0.074774
# 3     1.430157  0.637064  1.702742
# 4    -0.777871  0.955113  0.739921
# ...        ...       ...       ...
# 9995 -0.608023  0.531047  0.221478
# 9996 -1.117568 -1.695300 -1.778227
# 9997  1.430157 -0.105052 -0.148837
# 9998 -0.098478  0.955113  0.888047
# 9999 -0.098478  0.955113  0.888047
#
# [10000 rows x 3 columns]

# %% [markdown]
# ## Reshape data to 4d array

# %%
df_length = len(df_conti_norm.columns)
input_data = df_conti_norm.to_numpy().reshape(-1, 1, 1, df_length)
input_data.shape
# Out:
# (10000, 1, 1, 3)

# %% [markdown]
# # Build PyTorch Dataset

# %% [markdown]
# ## Dataset class

# %%
class OlympicDataset(Dataset):
    
    def __init__(self, data: pd.DataFrame, transform=None):
        self.data = torch.from_numpy(data).float()
#         self.data = data
#         self.transform = transforms.Compose([transforms.ToTensor()]) 
        
    
    def __len__(self):
        return len(self.data)
    
    
    def __getitem__(self, idx):
        data_content = self.data[idx]
#         data_label = int(1)
#         return (data_content, data_label)
#         return self.transform((data_content, data_label))
#         return self.transform(data_content)
#         return (data_content, data_label)[0]
        return data_content

# %% [markdown]
# ## Pytorch Normalization

# %%
# loader_all = DataLoader(input_data, batch_size=len(input_data), num_workers=1)
# data = next(iter(loader_all))
# mean = float(data.mean().detach().numpy())
# std = float(data.std().detach().numpy())

# %%
# transforms = transforms.Compose(
#     [transforms.ToTensor(), transforms.Normalize(mean, std)]
# )

transforms = transforms.Compose(
    [transforms.ToTensor()]
)

# %% [markdown]
# # Build GAN

# %% [markdown]
# ## Hyperparameters

# %%
# Hyperparameters etc.
device = "cuda" if torch.cuda.is_available() else "cpu"
lr = 3e-4
z_dim = 64 # 128, 256
# image_dim = 5 * 5 * 1  # 25
# image_dim = 1 * 5 * 1  # 5
image_dim = 1 * df_length * 1


batch_size = 32
num_epochs = 200

fixed_noise = torch.randn((batch_size, z_dim)).to(device)

# %% [markdown]
# ## Dataset and DataLoader

# %%
dataset = OlympicDataset(input_data, transform=transforms)
# dataset = OlympicDataset(input_data, transform=None)

loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, in_features):
        super().__init__()
        self.disc = nn.Sequential(
            nn.Linear(in_features, 128),
            nn.LeakyReLU(0.01),
            nn.Linear(128, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.disc(x)

disc = Discriminator(image_dim).to(device)

# %% [markdown]
# ## Generator

# %%
class Generator(nn.Module):
    def __init__(self, z_dim, img_dim):
        super().__init__()
        self.gen = nn.Sequential(
            nn.Linear(z_dim, 256),
            nn.LeakyReLU(0.01),
            nn.Linear(256, img_dim),
#             nn.Tanh(),  # normalize inputs to [-1, 1] so make outputs [-1, 1]
        )

    def forward(self, x):
        return self.gen(x)
    
gen = Generator(z_dim, image_dim).to(device)

# %% [markdown]
# ## Optimizer

# %%
opt_disc = optim.Adam(disc.parameters(), lr=lr)
opt_gen = optim.Adam(gen.parameters(), lr=lr)
criterion = nn.BCELoss()

# %% [markdown]
# ## Tensorboard

# %%
# writer_fake = SummaryWriter(f"logs/fake")
# writer_real = SummaryWriter(f"logs/real")

# %% [markdown]
# # Train/Test

# %%
step = 0
for epoch in range(num_epochs):
#     for batch_idx, (real, _) in enumerate(loader):
    for batch_idx, real in enumerate(loader):

#         real = real.view(-1, 25).to(device)
#         real = real.view(-1, 5).to(device)
        real = real.view(-1, 1*df_length).to(device)

        batch_size = real.shape[0]

        ### Train Discriminator: max log(D(x)) + log(1 - D(G(z)))
        noise = torch.randn(batch_size, z_dim).to(device)
        fake = gen(noise)
        disc_real = disc(real).view(-1)
        lossD_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = disc(fake).view(-1)
        lossD_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        lossD = (lossD_real + lossD_fake) / 2
        disc.zero_grad()
        lossD.backward(retain_graph=True)
        opt_disc.step()

        ### Train Generator: min log(1 - D(G(z))) <-> max log(D(G(z))
        # where the second option of maximizing doesn't suffer from
        # saturating gradients
        output = disc(fake).view(-1)
        lossG = criterion(output, torch.ones_like(output))
        gen.zero_grad()
        lossG.backward()
        opt_gen.step()

        if batch_idx == 0:
            print(
                f"Epoch [{epoch}/{num_epochs}] Batch {batch_idx}/{len(loader)} \
                      Loss D: {lossD:.4f}, loss G: {lossG:.4f}"
            )

            with torch.no_grad():
#                 fake = gen(fixed_noise).reshape(-1, 1, 5, 5)
#                 data = real.reshape(-1, 1, 5, 5)
                
#                 fake = gen(fixed_noise).reshape(-1, 1, 1, 5)
#                 data = real.reshape(-1, 1, 1, 5)

                fake = gen(fixed_noise).reshape(-1, 1, 1, df_length)
                data = real.reshape(-1, 1, 1, df_length)
    
                img_grid_fake = torchvision.utils.make_grid(fake, normalize=True)
                img_grid_real = torchvision.utils.make_grid(data, normalize=True)

#                 writer_fake.add_image(
#                     "Fake Data", img_grid_fake, global_step=step
#                 )
#                 writer_real.add_image(
#                     "Real Data", img_grid_real, global_step=step
#                 )
                step += 1
# Out:
# Epoch [0/200] Batch 0/313                       Loss D: 0.6982, loss G: 0.6406
# Epoch [1/200] Batch 0/313                       Loss D: 0.5377, loss G: 1.1310
# Epoch [2/200] Batch 0/313                       Loss D: 0.6778, loss G: 0.7434
# Epoch [3/200] Batch 0/313                       Loss D: 0.7791, loss G: 0.5496
# Epoch [4/200] Batch 0/313                       Loss D: 0.7047, loss G: 0.6244
# Epoch [5/200] Batch 0/313                       Loss D: 0.6841, loss G: 0.7741
# Epoch [6/200] Batch 0/313                       Loss D: 0.6905, loss G: 0.6626
# Epoch [7/200] Batch 0/313                       Loss D: 0.7651, loss G: 0.6261
# Epoch [8/200] Batch 0/313                       Loss D: 0.7599, loss G: 0.7585
# Epoch [9/200] Batch 0/313                       Loss D: 0.5835, loss G: 0.8490
# Epoch [10/200] Batch 0/313                       Loss D: 0.6742, loss G: 0.7630
# Epoch [11/200] Batch 0/313                       Loss D: 0.6257, loss G: 0.7867
# Epoch [12/200] Batch 0/313                       Loss D: 0.6847, loss G: 0.7428
# Epoch [13/200] Batch 0/313                       Loss D: 0.6686, loss G: 0.7109
# Epoch [14/200] Batch 0/313                       Loss D: 0.6935, loss G: 0.6776
# Epoch [15/200] Batch 0/313                       Loss D: 0.6148, loss G: 0.9361
# Epoch [16/200] Batch 0/313                       Loss D: 0.6921, loss G: 0.6382
# Epoch [17/200] Batch 0/313                       Loss D: 0.6833, loss G: 0.7226
# Epoch [18/200] Batch 0/313                       Loss D: 0.7508, loss G: 0.5556
# Epoch [19/200] Batch 0/313                       Loss D: 0.6699, loss G: 0.6230
# Epoch [20/200] Batch 0/313                       Loss D: 0.8120, loss G: 0.6623
# Epoch [21/200] Batch 0/313                       Loss D: 0.7191, loss G: 0.6487
# Epoch [22/200] Batch 0/313                       Loss D: 0.6654, loss G: 0.7365
# Epoch [23/200] Batch 0/313                       Loss D: 0.6834, loss G: 0.7327
# Epoch [24/200] Batch 0/313                       Loss D: 0.6767, loss G: 0.7129
# Epoch [25/200] Batch 0/313                       Loss D: 0.6930, loss G: 0.7090
# Epoch [26/200] Batch 0/313                       Loss D: 0.6991, loss G: 0.7038
# Epoch [27/200] Batch 0/313                       Loss D: 0.6902, loss G: 0.6901
# Epoch [28/200] Batch 0/313                       Loss D: 0.6820, loss G: 0.7288
# Epoch [29/200] Batch 0/313                       Loss D: 0.7098, loss G: 0.6685
# Epoch [30/200] Batch 0/313                       Loss D: 0.6967, loss G: 0.6617
# Epoch [31/200] Batch 0/313                       Loss D: 0.6661, loss G: 0.7275
# Epoch [32/200] Batch 0/313                       Loss D: 0.7281, loss G: 0.6395
# Epoch [33/200] Batch 0/313                       Loss D: 0.6965, loss G: 0.6971
# Epoch [34/200] Batch 0/313                       Loss D: 0.6909, loss G: 0.7291
# Epoch [35/200] Batch 0/313                       Loss D: 0.6873, loss G: 0.7481
# Epoch [36/200] Batch 0/313                       Loss D: 0.7170, loss G: 0.7216
# Epoch [37/200] Batch 0/313                       Loss D: 0.7144, loss G: 0.6791
# Epoch [38/200] Batch 0/313                       Loss D: 0.6876, loss G: 0.7170
# Epoch [39/200] Batch 0/313                       Loss D: 0.6893, loss G: 0.6730
# Epoch [40/200] Batch 0/313                       Loss D: 0.6810, loss G: 0.6655
# Epoch [41/200] Batch 0/313                       Loss D: 0.6822, loss G: 0.6897
# Epoch [42/200] Batch 0/313                       Loss D: 0.7080, loss G: 0.6673
# Epoch [43/200] Batch 0/313                       Loss D: 0.7144, loss G: 0.6542
# Epoch [44/200] Batch 0/313                       Loss D: 0.7077, loss G: 0.6630
# Epoch [45/200] Batch 0/313                       Loss D: 0.7081, loss G: 0.6986
# Epoch [46/200] Batch 0/313                       Loss D: 0.6748, loss G: 0.7202
# Epoch [47/200] Batch 0/313                       Loss D: 0.7232, loss G: 0.7347
# Epoch [48/200] Batch 0/313                       Loss D: 0.6967, loss G: 0.7405
# Epoch [49/200] Batch 0/313                       Loss D: 0.6863, loss G: 0.7245
# Epoch [50/200] Batch 0/313                       Loss D: 0.6999, loss G: 0.6820
# Epoch [51/200] Batch 0/313                       Loss D: 0.7550, loss G: 0.6195
# Epoch [52/200] Batch 0/313                       Loss D: 0.6767, loss G: 0.7199
# Epoch [53/200] Batch 0/313                       Loss D: 0.7339, loss G: 0.6056
# Epoch [54/200] Batch 0/313                       Loss D: 0.6794, loss G: 0.7006
# Epoch [55/200] Batch 0/313                       Loss D: 0.7107, loss G: 0.6793
# Epoch [56/200] Batch 0/313                       Loss D: 0.7080, loss G: 0.6773
# Epoch [57/200] Batch 0/313                       Loss D: 0.7152, loss G: 0.6603
# Epoch [58/200] Batch 0/313                       Loss D: 0.6935, loss G: 0.6975
# Epoch [59/200] Batch 0/313                       Loss D: 0.7116, loss G: 0.6624
# Epoch [60/200] Batch 0/313                       Loss D: 0.7260, loss G: 0.7267
# Epoch [61/200] Batch 0/313                       Loss D: 0.6950, loss G: 0.7243
# Epoch [62/200] Batch 0/313                       Loss D: 0.7145, loss G: 0.6663
# Epoch [63/200] Batch 0/313                       Loss D: 0.6794, loss G: 0.7098
# Epoch [64/200] Batch 0/313                       Loss D: 0.6936, loss G: 0.7484
# Epoch [65/200] Batch 0/313                       Loss D: 0.7209, loss G: 0.7137
# Epoch [66/200] Batch 0/313                       Loss D: 0.6861, loss G: 0.7233
# Epoch [67/200] Batch 0/313                       Loss D: 0.7010, loss G: 0.6742
# Epoch [68/200] Batch 0/313                       Loss D: 0.6859, loss G: 0.7176
# Epoch [69/200] Batch 0/313                       Loss D: 0.6852, loss G: 0.6509
# Epoch [70/200] Batch 0/313                       Loss D: 0.6666, loss G: 0.7401
# Epoch [71/200] Batch 0/313                       Loss D: 0.7026, loss G: 0.6784
# Epoch [72/200] Batch 0/313                       Loss D: 0.6844, loss G: 0.7767
# Epoch [73/200] Batch 0/313                       Loss D: 0.6803, loss G: 0.7130
# Epoch [74/200] Batch 0/313                       Loss D: 0.7106, loss G: 0.6281
# Epoch [75/200] Batch 0/313                       Loss D: 0.6496, loss G: 0.7426
# Epoch [76/200] Batch 0/313                       Loss D: 0.6854, loss G: 0.7274
# Epoch [77/200] Batch 0/313                       Loss D: 0.7073, loss G: 0.6907
# Epoch [78/200] Batch 0/313                       Loss D: 0.7002, loss G: 0.6852
# Epoch [79/200] Batch 0/313                       Loss D: 0.7003, loss G: 0.6603
# Epoch [80/200] Batch 0/313                       Loss D: 0.6758, loss G: 0.7408
# Epoch [81/200] Batch 0/313                       Loss D: 0.7243, loss G: 0.6352
# Epoch [82/200] Batch 0/313                       Loss D: 0.6680, loss G: 0.6874
# Epoch [83/200] Batch 0/313                       Loss D: 0.6955, loss G: 0.7017
# Epoch [84/200] Batch 0/313                       Loss D: 0.6777, loss G: 0.7395
# Epoch [85/200] Batch 0/313                       Loss D: 0.7039, loss G: 0.6816
# Epoch [86/200] Batch 0/313                       Loss D: 0.6533, loss G: 0.7189
# Epoch [87/200] Batch 0/313                       Loss D: 0.7038, loss G: 0.6111
# Epoch [88/200] Batch 0/313                       Loss D: 0.6984, loss G: 0.6872
# Epoch [89/200] Batch 0/313                       Loss D: 0.6450, loss G: 0.6770
# Epoch [90/200] Batch 0/313                       Loss D: 0.7013, loss G: 0.7335
# Epoch [91/200] Batch 0/313                       Loss D: 0.6822, loss G: 0.7681
# Epoch [92/200] Batch 0/313                       Loss D: 0.6917, loss G: 0.8306
# Epoch [93/200] Batch 0/313                       Loss D: 0.6585, loss G: 0.7400
# Epoch [94/200] Batch 0/313                       Loss D: 0.6751, loss G: 0.6541
# Epoch [95/200] Batch 0/313                       Loss D: 0.6865, loss G: 0.7146
# Epoch [96/200] Batch 0/313                       Loss D: 0.6754, loss G: 0.7098
# Epoch [97/200] Batch 0/313                       Loss D: 0.6575, loss G: 0.7845
# Epoch [98/200] Batch 0/313                       Loss D: 0.6621, loss G: 0.8056
# Epoch [99/200] Batch 0/313                       Loss D: 0.6958, loss G: 0.6856
# Epoch [100/200] Batch 0/313                       Loss D: 0.7052, loss G: 0.7378
# Epoch [101/200] Batch 0/313                       Loss D: 0.6878, loss G: 0.7156
# Epoch [102/200] Batch 0/313                       Loss D: 0.6808, loss G: 0.7752
# Epoch [103/200] Batch 0/313                       Loss D: 0.7088, loss G: 0.6493
# Epoch [104/200] Batch 0/313                       Loss D: 0.6923, loss G: 0.6923
# Epoch [105/200] Batch 0/313                       Loss D: 0.6827, loss G: 0.7234
# Epoch [106/200] Batch 0/313                       Loss D: 0.6830, loss G: 0.6796
# Epoch [107/200] Batch 0/313                       Loss D: 0.7119, loss G: 0.6783
# Epoch [108/200] Batch 0/313                       Loss D: 0.6861, loss G: 0.7224
# Epoch [109/200] Batch 0/313                       Loss D: 0.6942, loss G: 0.7107
# Epoch [110/200] Batch 0/313                       Loss D: 0.6920, loss G: 0.6915
# Epoch [111/200] Batch 0/313                       Loss D: 0.6719, loss G: 0.7239
# Epoch [112/200] Batch 0/313                       Loss D: 0.6857, loss G: 0.7362
# Epoch [113/200] Batch 0/313                       Loss D: 0.7154, loss G: 0.7214
# Epoch [114/200] Batch 0/313                       Loss D: 0.6789, loss G: 0.6895
# Epoch [115/200] Batch 0/313                       Loss D: 0.7084, loss G: 0.6409
# Epoch [116/200] Batch 0/313                       Loss D: 0.6813, loss G: 0.7494
# Epoch [117/200] Batch 0/313                       Loss D: 0.7034, loss G: 0.6606
# Epoch [118/200] Batch 0/313                       Loss D: 0.6869, loss G: 0.7057
# Epoch [119/200] Batch 0/313                       Loss D: 0.6965, loss G: 0.6979
# Epoch [120/200] Batch 0/313                       Loss D: 0.6916, loss G: 0.7521
# Epoch [121/200] Batch 0/313                       Loss D: 0.7167, loss G: 0.6619
# Epoch [122/200] Batch 0/313                       Loss D: 0.6801, loss G: 0.6883
# Epoch [123/200] Batch 0/313                       Loss D: 0.6989, loss G: 0.6881
# Epoch [124/200] Batch 0/313                       Loss D: 0.6964, loss G: 0.7063
# Epoch [125/200] Batch 0/313                       Loss D: 0.6948, loss G: 0.7112
# Epoch [126/200] Batch 0/313                       Loss D: 0.6924, loss G: 0.6771
# Epoch [127/200] Batch 0/313                       Loss D: 0.6840, loss G: 0.7080
# Epoch [128/200] Batch 0/313                       Loss D: 0.6869, loss G: 0.6772
# Epoch [129/200] Batch 0/313                       Loss D: 0.6952, loss G: 0.7059
# Epoch [130/200] Batch 0/313                       Loss D: 0.6891, loss G: 0.7401
# Epoch [131/200] Batch 0/313                       Loss D: 0.6929, loss G: 0.7187
# Epoch [132/200] Batch 0/313                       Loss D: 0.6797, loss G: 0.7467
# Epoch [133/200] Batch 0/313                       Loss D: 0.7010, loss G: 0.7053
# Epoch [134/200] Batch 0/313                       Loss D: 0.6954, loss G: 0.6957
# Epoch [135/200] Batch 0/313                       Loss D: 0.7026, loss G: 0.6915
# Epoch [136/200] Batch 0/313                       Loss D: 0.7099, loss G: 0.6698
# Epoch [137/200] Batch 0/313                       Loss D: 0.6998, loss G: 0.6813
# Epoch [138/200] Batch 0/313                       Loss D: 0.6926, loss G: 0.7124
# Epoch [139/200] Batch 0/313                       Loss D: 0.6955, loss G: 0.6991
# Epoch [140/200] Batch 0/313                       Loss D: 0.6894, loss G: 0.7264
# Epoch [141/200] Batch 0/313                       Loss D: 0.6955, loss G: 0.6997
# Epoch [142/200] Batch 0/313                       Loss D: 0.6904, loss G: 0.6935
# Epoch [143/200] Batch 0/313                       Loss D: 0.6886, loss G: 0.6956
# Epoch [144/200] Batch 0/313                       Loss D: 0.7115, loss G: 0.6632
# Epoch [145/200] Batch 0/313                       Loss D: 0.6911, loss G: 0.6966
# Epoch [146/200] Batch 0/313                       Loss D: 0.7024, loss G: 0.6888
# Epoch [147/200] Batch 0/313                       Loss D: 0.6890, loss G: 0.6769
# Epoch [148/200] Batch 0/313                       Loss D: 0.6861, loss G: 0.6789
# Epoch [149/200] Batch 0/313                       Loss D: 0.6905, loss G: 0.6886
# Epoch [150/200] Batch 0/313                       Loss D: 0.6952, loss G: 0.7145
# Epoch [151/200] Batch 0/313                       Loss D: 0.7045, loss G: 0.6985
# Epoch [152/200] Batch 0/313                       Loss D: 0.6918, loss G: 0.7150
# Epoch [153/200] Batch 0/313                       Loss D: 0.6900, loss G: 0.6964
# Epoch [154/200] Batch 0/313                       Loss D: 0.6953, loss G: 0.6957
# Epoch [155/200] Batch 0/313                       Loss D: 0.7010, loss G: 0.6883
# Epoch [156/200] Batch 0/313                       Loss D: 0.6937, loss G: 0.6987
# Epoch [157/200] Batch 0/313                       Loss D: 0.6936, loss G: 0.7061
# Epoch [158/200] Batch 0/313                       Loss D: 0.6858, loss G: 0.7070
# Epoch [159/200] Batch 0/313                       Loss D: 0.6872, loss G: 0.6890
# Epoch [160/200] Batch 0/313                       Loss D: 0.7130, loss G: 0.6688
# Epoch [161/200] Batch 0/313                       Loss D: 0.6932, loss G: 0.6774
# Epoch [162/200] Batch 0/313                       Loss D: 0.6916, loss G: 0.6938
# Epoch [163/200] Batch 0/313                       Loss D: 0.6903, loss G: 0.6914
# Epoch [164/200] Batch 0/313                       Loss D: 0.6897, loss G: 0.6895
# Epoch [165/200] Batch 0/313                       Loss D: 0.6826, loss G: 0.6978
# Epoch [166/200] Batch 0/313                       Loss D: 0.6929, loss G: 0.6914
# Epoch [167/200] Batch 0/313                       Loss D: 0.7008, loss G: 0.6881
# Epoch [168/200] Batch 0/313                       Loss D: 0.6969, loss G: 0.6970
# Epoch [169/200] Batch 0/313                       Loss D: 0.7013, loss G: 0.6646
# Epoch [170/200] Batch 0/313                       Loss D: 0.6921, loss G: 0.7113
# Epoch [171/200] Batch 0/313                       Loss D: 0.6983, loss G: 0.6882
# Epoch [172/200] Batch 0/313                       Loss D: 0.6858, loss G: 0.7107
# Epoch [173/200] Batch 0/313                       Loss D: 0.6924, loss G: 0.6952
# Epoch [174/200] Batch 0/313                       Loss D: 0.6982, loss G: 0.6813
# Epoch [175/200] Batch 0/313                       Loss D: 0.6882, loss G: 0.6962
# Epoch [176/200] Batch 0/313                       Loss D: 0.7362, loss G: 0.6372
# Epoch [177/200] Batch 0/313                       Loss D: 0.6951, loss G: 0.6844
# Epoch [178/200] Batch 0/313                       Loss D: 0.6839, loss G: 0.7524
# Epoch [179/200] Batch 0/313                       Loss D: 0.6922, loss G: 0.7096
# Epoch [180/200] Batch 0/313                       Loss D: 0.6855, loss G: 0.6984
# Epoch [181/200] Batch 0/313                       Loss D: 0.6920, loss G: 0.6964
# Epoch [182/200] Batch 0/313                       Loss D: 0.6876, loss G: 0.7727
# Epoch [183/200] Batch 0/313                       Loss D: 0.6938, loss G: 0.6801
# Epoch [184/200] Batch 0/313                       Loss D: 0.6975, loss G: 0.6910
# Epoch [185/200] Batch 0/313                       Loss D: 0.7031, loss G: 0.6661
# Epoch [186/200] Batch 0/313                       Loss D: 0.6929, loss G: 0.6859
# Epoch [187/200] Batch 0/313                       Loss D: 0.6844, loss G: 0.7328
# Epoch [188/200] Batch 0/313                       Loss D: 0.7049, loss G: 0.6691
# Epoch [189/200] Batch 0/313                       Loss D: 0.6998, loss G: 0.7166
# Epoch [190/200] Batch 0/313                       Loss D: 0.6907, loss G: 0.6747
# Epoch [191/200] Batch 0/313                       Loss D: 0.7045, loss G: 0.6728
# Epoch [192/200] Batch 0/313                       Loss D: 0.6900, loss G: 0.7065
# Epoch [193/200] Batch 0/313                       Loss D: 0.6887, loss G: 0.7040
# Epoch [194/200] Batch 0/313                       Loss D: 0.6967, loss G: 0.6464
# Epoch [195/200] Batch 0/313                       Loss D: 0.6895, loss G: 0.6934
# Epoch [196/200] Batch 0/313                       Loss D: 0.6771, loss G: 0.6933
# Epoch [197/200] Batch 0/313                       Loss D: 0.7338, loss G: 0.6794
# Epoch [198/200] Batch 0/313                       Loss D: 0.6811, loss G: 0.7460
# Epoch [199/200] Batch 0/313                       Loss D: 0.6889, loss G: 0.6916

# %% [markdown]
# # Generate synthetic output

# %%
fake_df = pd.DataFrame(fake.flatten().reshape(-1, df_length).detach().numpy())
fake_df = fake_df.rename(columns = {i: df_conti.columns[i] for i in range(df_conti.columns.shape[0])})
fake_df
# Out:
#          Age    Height    Weight
# 0  -0.221446  1.193498  0.671830
# 1   0.031339  0.090261 -0.205356
# 2  -0.984401 -0.517960 -0.916570
# 3   0.227838  1.871510  1.168838
# 4  -0.978560 -1.269928 -1.075238
# 5  -1.171800 -0.592140 -1.178437
# 6   0.632883  0.390625  0.030425
# 7   0.121439  0.510471 -0.202529
# 8  -0.354101  0.060950 -0.349296
# 9  -0.356742  2.129166  1.675217
# 10  0.457088  0.178019 -0.003519
# 11  0.382741  1.438790  0.835075
# 12  0.165672  0.308989 -0.345412
# 13  0.792042  0.277766  0.058490
# 14 -0.985111  0.815162 -0.014780
# 15  0.269409  1.489737  0.997766

# %%
final = denorm(fake_df, norm_list, norm_types, dict_conti).apply(np.ceil).astype('int64')

# %%
final
# Out:
#        Age  Height  Weight
# 0       25     188      82
# 1       26     177      70
# 2       20     172      60
# 3       27     194      88
# 4       20     165      58
# ...    ...     ...     ...
# 10027   20     192      84
# 10028   26     179      72
# 10029   23     172      65
# 10030   26     171      60
# 10031   21     190      75
#
# [10032 rows x 3 columns]

# %%
df_real = df[['ID', 'Age','Height', 'Weight']].astype('int64')
df_real
# Out:
#         ID  Age  Height  Weight
# 0        1   24     180      80
# 1        2   23     170      60
# 2        3   24     175      71
# 3        4   34     182      95
# 4        5   21     185      82
# ...    ...  ...     ...     ...
# 9995  7390   22     181      75
# 9996  7391   19     160      48
# 9997  7392   34     175      70
# 9998  7393   25     185      84
# 9999  7393   25     185      84
#
# [10000 rows x 4 columns]

# %%
for i in tqdm(range(len(df_real)//len(final) + 1)):
    noise = torch.randn(batch_size, z_dim).to(device)
    fake = gen(noise)
    fake_df = pd.DataFrame(fake.flatten().reshape(-1, df_length).detach().numpy())
#     fake_df = fake_df.rename(columns = {0: df_conti.columns[0], 1: df_conti.columns[1],
#                              2: df_conti.columns[2], 3: df_conti.columns[3],
#                              4: df_conti.columns[4]})
    fake_df = fake_df.rename(columns = {i: df_conti.columns[i] for i in range(df_conti.columns.shape[0])})
    demo = denorm(fake_df, norm_list, norm_types, dict_conti).apply(np.ceil).astype('int64')
    final = pd.concat([final, demo]).reset_index(drop=True)
# Out:
#   0%|          | 0/626 [00:00<?, ?it/s]

# %%
# df_fake = final.reset_index().rename(columns={'index': 'ID'}).iloc[0:len(df_real), :].astype('int64')
df_fake = final.reset_index().rename(columns={'index': 'ID'}).astype('int64')

# %%
df_fake
# Out:
#           ID  Age  Height  Weight
# 0          0   25     188      82
# 1          1   26     177      70
# 2          2   20     172      60
# 3          3   27     194      88
# 4          4   20     165      58
# ...      ...  ...     ...     ...
# 10027  10027   20     192      84
# 10028  10028   26     179      72
# 10029  10029   23     172      65
# 10030  10030   26     171      60
# 10031  10031   21     190      75
#
# [10032 rows x 4 columns]

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Draw columns

# %%
metadata = Metadata()

# %%
metadata.add_table(name='olympic',
                  data=df_real,
                  primary_key = 'ID')

# %%
metadata = metadata.get_table_meta('olympic')

# %%
get_column_plot(
    real_data=df_real,
    synthetic_data=df_fake,
    metadata=metadata,
    column_name='Age'
)
# Out:
# <div>                            <div id="1a3f9335-11ff-4bbb-8c59-2ca989999cd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a3f9335-11ff-4bbb-8c59-2ca989999cd6")) {                    Plotly.newPlot(                        "1a3f9335-11ff-4bbb-8c59-2ca989999cd6",                        [{"legendgroup":"Real","marker":{"color":"#000036"},"mode":"lines","name":"Real","showlegend":true,"x":[12.0,12.144,12.288,12.432,12.576,12.72,12.864,13.008,13.152,13.296,13.44,13.584,13.728,13.872,14.016,14.16,14.304,14.448,14.592,14.736,14.879999999999999,15.024000000000001,15.168,15.312,15.456,15.6,15.744,15.888,16.032,16.176000000000002,16.32,16.464,16.608,16.752,16.896,17.04,17.184,17.328,17.472,17.616,17.759999999999998,17.904,18.048000000000002,18.192,18.336,18.48,18.624,18.768,18.912,19.056,19.2,19.344,19.488,19.631999999999998,19.776,19.92,20.064,20.208,20.352,20.496000000000002,20.64,20.784,20.928,21.072,21.216,21.36,21.503999999999998,21.648,21.792,21.936,22.08,22.224,22.368000000000002,22.512,22.656,22.8,22.944000000000003,23.